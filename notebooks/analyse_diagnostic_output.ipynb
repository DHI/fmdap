# %% [markdown]
# # Analyse diagnostic output
# The diagnostic_output module can be used for finding forecast and analysis part of diagnostic output files and to calculate increments.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from fmdap.diagnostic_output import DiagnosticOutput

# %%
do = DiagnosticOutput()

# %%
fn = '../tests/testdata/Diagnostics_F16.dfs0'
do.read(fn)

# %%
increments = do.get_all_increments_as_array()
plt.hist(increments,bins=100);

# %%
dfi = do.get_increments()
dfi.plot(figsize=(12,5));
# Out:
# <AxesSubplot:>

# %%
dfa = do.get_total_analysis()
dfa.plot(figsize=(12,5));
# Out:
# <AxesSubplot:>
