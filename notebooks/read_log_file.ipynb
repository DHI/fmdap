# %% [markdown]
# # Read log file
# Use log_helper module to extract DA statistics from log file.

# %%
from fmdap import log_helper

# %%
filename1 = '../tests/testdata/SW_SNS_T1_EnKF_sch1.log'

# %%
df_da_f, df_da_a, df_qa_f, df_qa_a = log_helper.extract_DA_statistics(filename1)

# %%
df_da_a
# Out:
#        name  n_points   bias   rmse  max_err  stdev
# id
# 1   Hm0_EPL        13  0.297  0.363    0.804  0.148
# 2   Hm0_K14        13  0.229  0.277    0.585  0.136
# 4    Hm0_F3        13 -0.415  0.497    1.100  0.142

# %%
df_qa_a
# Out:
#        name  n_points    bias   rmse  max_err  stdev
# id
# 3   Hm0_F16         5 -0.0409  0.139    0.464  0.147

# %%
df_da_a.plot.bar(x='name', y='rmse');
